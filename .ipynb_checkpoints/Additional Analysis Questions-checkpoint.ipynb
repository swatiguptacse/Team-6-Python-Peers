# %% [markdown]
# # Q1.Which demographic patients are prone to get Flu?

# %%
import pandas as pd
workbook_url = 'HospitalDatabase.xlsx'
Patients_df = pd.read_excel(workbook_url,sheet_name='Patients')
Discharges_df = pd.read_excel(workbook_url,sheet_name='Discharges')
merged = Patients_df.merge(Discharges_df, left_on='PatientID', right_on='PatientID')
df = merged.loc[(merged['PrimaryDiagnosis'] == "Flu")]
df['Race'].max()
# Out:
# 'White'

# %% [markdown]
# # Q2.Plot a graph by counting the no. of patients by Primary Diagnosis.

# %%
import pandas as pd
df=pd.read_excel('HospitalDatabase.xlsx', 'Discharges')
df['PrimaryDiagnosis'].value_counts().plot(kind='bar');

# %% [markdown]
# # Q3. Plot a graph to count of Providers based on ProviderSpecialty.

# %%
import pandas as pd
import numpy as np
df=pd.read_excel('HospitalDatabase.xlsx', 'Providers')
df['ProviderSpecialty'].value_counts().plot(kind='bar');

# %% [markdown]
# # Q4. Which reason of visit has minimum mortality rate.

# %%
import pandas as pd
import numpy as np
workbook_url = 'HospitalDatabase.xlsx'
EDVisits_df = pd.read_excel(workbook_url,sheet_name='EDVisits')
EDVisits_df
workbook_url = 'HospitalDatabase.xlsx'
Discharges_df = pd.read_excel(workbook_url,sheet_name='Discharges')
min_mortality_val=Discharges_df['ExpectedMortality'].min()
min_mortality_val
EDVisits_df['visit'] = (EDVisits_df['ReasonForVisit'])
EDVisits_df
merged = EDVisits_df.merge(Discharges_df, left_on='PatientID', right_on='PatientID')
merged
df = merged.loc[(merged['ExpectedMortality'] == min_mortality_val)]
df['ReasonForVisit']
# Out:
# 963    Bleeding
# Name: ReasonForVisit, dtype: object

# %% [markdown]
# # Q5. Find the count of White English Female.

# %%
import pandas as pd
df=pd.read_excel('HospitalDatabase.xlsx', 'Patients')
s_bool_and = ((df['Language'] == 'English') & (df['Gender'] == 'Female') & (df['Race'] == 'White'))
print(s_bool_and.sum())
# Out:
# 216

# %% [markdown]
# # Q6. Using a bar chart, which Service had the highest count of Expected Mortality?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_excel('HospitalDatabase.xlsx', 'Discharges')
sns.barplot(x = 'Service',
            y = 'ExpectedMortality',
            data = df) 
# Show the plot
plt.show()

# %%
# Answer : Neurology has the highest expected mortality.

# %% [markdown]
# # Q7. Get the FirstName, LastName of the Patients whose reason for visit is Fever.

# %%
import pandas as pd
workbook_url = 'HospitalDatabase.xlsx'
EDUnique_df = pd.read_excel(workbook_url,sheet_name='EDUnique')
EDUnique_df
workbook_url = 'HospitalDatabase.xlsx'
Patients_df = pd.read_excel(workbook_url,sheet_name='Patients')
Patients_df
sheets=pd.read_excel('HospitalDatabase.xlsx',sheet_name=['EDUnique','Patients'])
sheets 
Patients_df['FullName'] = (Patients_df['FirstName']+' '+Patients_df['LastName'])
Patients_df[EDUnique_df['ReasonForVisit']=='Fever']['FullName']
# Out:
# 15            Far Pardon
# 18      Daugherty Conner
# 28             Ted Scott
# 33               Ted Hue
# 39        Christian  Pow
#              ...
# 919       Kaylil Sharple
# 924       Cynthie Hurtic
# 926     Des Landsborough
# 933     Margalit Borland
# 939    Christian Kenford
# Name: FullName, Length: 172, dtype: object

# %% [markdown]
# # Q8. Make a pair plot on Ambulatory Visits table.

# %%
import pandas as pd
import seaborn as sns
workbook_url = 'HospitalDatabase.xlsx'
AmbulatoryVisits_df = pd.read_excel(workbook_url,sheet_name='AmbulatoryVisits')
AmbulatoryVisits_df
# Out:
#      VisitID  PatientMRN  ProviderID DateofVisit           DateScheduled  \
# 0        202         840          29  2019-03-19 2019-03-13 07:59:24.000
# 1        436         820          25  2019-03-19 2019-02-24 07:10:31.043
# 2        794         879          30  2019-04-02 2019-03-19 01:41:55.656
# 3        799         884          37  2019-03-03 2019-02-25 01:25:39.696
# 4        515          32          26  2019-03-16 2019-02-20 06:44:59.617
# ..       ...         ...         ...         ...                     ...
# 945      788         873           1  2019-03-27 2019-03-10 17:19:48.264
# 946      703         855          36  2019-03-12 2019-02-19 02:27:52.664
# 947      481         865          13  2019-05-03 2019-04-25 13:37:57.501
# 948      398         635          10  2019-02-09 2019-02-08 11:40:35.137
# 949      695         847          24  2019-03-04 2019-02-05 05:29:30.587
#
#      VisitDepartmentID     VisitType  BloodPressureSystolic  \
# 0                   10      Physical                  188.0
# 1                    3     Follow Up                  179.0
# 2                   11  Telemedicine                  133.0
# 3                    4  Telemedicine                  132.0
# 4                   11  Telemedicine                  131.0
# ..                 ...           ...                    ...
# 945                  5  Telemedicine                  187.0
# 946                 10     Follow Up                  182.0
# 947                 12           New                  150.0
# 948                  1      Physical                  177.0
# 949                 12     Follow Up                  165.0
#
#      BloodPressureDiastolic      Pulse VisitStatus
# 0                144.143427  83.044920     No Show
# 1                118.876808  90.309544     No Show
# 2                 98.749563  80.859776     No Show
# 3                 98.001270  82.184737     No Show
# 4                 85.115632  89.192362     No Show
# ..                      ...        ...         ...
# 945              126.695141  70.049167    Canceled
# 946              140.703502  73.380812    Canceled
# 947               84.841197  61.625454    Canceled
# 948              125.037534  53.287036    Canceled
# 949              116.879318  56.180317    Canceled
#
# [950 rows x 11 columns]

# %%
sns.pairplot(AmbulatoryVisits_df)

# %% [markdown]
# # Q9. Write a function to print the multipication table of the given number.

# %%
import numpy as np
num = int(input("Print the multiplication table of? "))
for i in range(1, 11):
   print(num, 'x', i, '=', num*i)
# Out:
# Print the multiplication table of? 8
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 8 x 10 = 80

# %% [markdown]
# # Q10. Number of patients on 'Home' based on primary diagnosis.

# %%
df=pd.read_excel('HospitalDatabase.xlsx', 'ReAdmissionRegistry')
df.groupby('PrimaryDiagnosis')['DischargeDisposition'].apply(lambda x: (x=='Home').sum()).reset_index(name='count')
# Out:
#       PrimaryDiagnosis  count
# 0                  AMI     42
# 1                 Afib      6
# 2           Broken Leg      6
# 3             Diabetes     48
# 4                Fever     15
# 5                  Flu     67
# 6        Heart Failure     53
# 7         Hip Fracture     20
# 8         Hypertension     34
# 9       Kidney Failure     18
# 10    Knee Replacement     20
# 11          Laceration     26
# 12            Migraine     12
# 13                Pain      5
# 14           Pneumonia    153
# 15  Spinal Cord Injury      0
# 16              Stroke     52
